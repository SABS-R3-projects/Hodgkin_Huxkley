# %%
import Hodgkin_Huxley_class as hh
import Fitzhugh_Nagumo_class as fh

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
hsim = hh.Hodgkin_Huxley()

# %%
cm, gl, gna, gk, vl, vna, vk = 1, 0.3, 120, 36, 10.6, 115, -12

# %%
params  = hsim.default_params
#hsim.Ifunc = current

# %%
# Values: 6.3, 9.8, 153
# https://arxiv.org/pdf/1001.2474.pdf

def current(t):
    #return (t < 100) * 6.2 + (t >= 100) * (t < 400) * 8 + (t >= 400) * (t < 600) * 20 + (t >= 700) * 200
    return 6.8

hsim.Ifunc = current

# %%
times = np.arange(0,1000,0.1)
sol = hsim.simulate(params, times)

# %%
plt.figure()
plt.plot(times,sol[:,0])
plt.show()

# %%
hsim.Vm0
# Out:
# -70.0

# %%
hsim.I_inj(200)
# Out:
# 10

# %%
fsim = fh.Fitzhugh_Nagumo()

# %%
def current(t):
    return 0.4 * ( t> 200)

# %%
fsim.Ifunc = current

# %%
dparam = fsim.default_params

# %%
sol = fsim.simulate(dparam, times)

# %%
plt.figure()
plt.plot(times, sol)
plt.show()
